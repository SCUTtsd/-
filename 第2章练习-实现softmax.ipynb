# %% [markdown]
# # softmax实现练习
#  在本章练习中我们将逐步完成：
# * 1.熟悉使用CIFAR-10 数据集
# * 2.编码softmax_loss_naive函数 使用显式循环计算损失函数以及梯度
# * 3.编码softmax_loss_vectorized函数  使用向量化表达计算损失函数以及梯度
# * 4.编码最小批量梯度下降算法 训练softmax分类器
# * 5.使用验证数据选择超参数

# %%
#-*- coding: utf-8 -*-
import random
import numpy as np
from utils.data_utils import load_CIFAR10
from classifiers.chapter2 import *
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) 
# %load_ext autoreload
# %autoreload 2

# %%
# 导入 CIFAR-10 数据.
cifar10_dir = 'datasets/cifar-10-batches-py'
X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)

# 查看数据
print('训练数据（数据个数，数据维度）: ', X_train.shape)
print('训练数据标记（数据标记个数，）: ', y_train.shape)
print('测试数据（数据个数，数据维度）: ', X_test.shape)
print('测试数据标记（数据标记个数，）: ', y_test.shape)
# Out:
# 训练数据（数据个数，数据维度）:  (50000, 32, 32, 3)
# 训练数据标记（数据标记个数，）:  (50000,)
# 测试数据（数据个数，数据维度）:  (10000, 32, 32, 3)
# 测试数据标记（数据标记个数，）:  (10000,)

# %%
# 数据可视化.
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
num_classes = len(classes)
samples_per_class = 7
for y, cls in enumerate(classes):
    idxs = np.flatnonzero(y_train == y)
    idxs = np.random.choice(idxs, samples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt_idx = i * num_classes + y + 1
        plt.subplot(samples_per_class, num_classes, plt_idx)
        plt.imshow(X_train[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls)
plt.show()

# %% [markdown]
# ## 1.数据预处理
# 在通常情况下，我们需要对输入数据进行归一化处理，也就是使得数据呈均值为零，方差为1的标准正态分布。由于图像的特征范围在[0,255]，其方差已经被约束了，我们只需要将数据进行零均值中心化处理即可，不需要将数据压缩在[-1,1]范围(当然，你也可以进行此项处理)。

# %%
def get_CIFAR10_data(num_training=49000, num_validation=100, num_test=10000, num_sample=250):
  # 导入 CIFAR-10 data
  cifar10_dir = 'datasets/cifar-10-batches-py'
  X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
  
  # 采样数据
  mask = range(num_training, num_training + num_validation)
  X_val = X_train[mask]
  y_val = y_train[mask]
  mask = range(num_training)
  X_train = X_train[mask]
  y_train = y_train[mask]
  mask = range(num_test)
  X_test = X_test[mask]
  y_test = y_test[mask]
  mask = np.random.choice(num_training, num_sample, replace=False)
  X_sample = X_train[mask]
  y_sample = y_train[mask]
  
  # 将数据重塑成（数据个数，维度）形状
  X_train = np.reshape(X_train, (X_train.shape[0], -1))
  X_val = np.reshape(X_val, (X_val.shape[0], -1))
  X_test = np.reshape(X_test, (X_test.shape[0], -1))
  X_sample = np.reshape(X_sample, (X_sample.shape[0], -1))
  
  # 数据预处理，减去其均值
  mean_image = np.mean(X_train, axis = 0)
  X_train -= mean_image
  X_val -= mean_image
  X_test -= mean_image
  X_sample -= mean_image
  
  #在每列数据中加入偏置项
  X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
  X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
  X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
  X_sample = np.hstack([X_sample, np.ones((X_sample.shape[0], 1))])
  
  return X_train, y_train, X_val, y_val, X_test, y_test, X_sample, y_sample

X_train, y_train, X_val, y_val, X_test, y_test, X_sample, y_sample = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('sample data shape: ', X_sample.shape)
print('sample labels shape: ', y_sample.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (100, 3073)
# Validation labels shape:  (100,)
# Test data shape:  (10000, 3073)
# Test labels shape:  (10000,)
# sample data shape:  (250, 3073)
# sample labels shape:  (250,)

# %% [markdown]
# ## 2.使用显式循环计算损失函数以及梯度

# %%
#首先我们将用循环的方式实现softmax的损失函数（代价函数）
#打开 classifiers/chapter2/softmax_loss.py 文件并实现softmax_loss_naive函数
#完成之后运行该单元代码
from classifiers.chapter2.softmax_loss import softmax_loss_naive
import time

# 初始化权重
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_sample, y_sample, 0.0)

# 你的初始化损失值应该接近于 -log(0.1).
print('你实现的softmax损失值loss: %f' % loss)
print('正确的损失值: %f' % ( -np.log(0.1) ))
# Out:
# 你实现的softmax损失值loss: 2.322968
# 正确的损失值: 2.302585

# %%
# 使用数值梯度检验你已实现的softmax_loss_naive
# 你实现的梯度应该要接近于数值梯度
from utils.gradient_check import grad_check_sparse
loss, grad = softmax_loss_naive(W, X_sample, y_sample, 0.0)

print('检验无权重衰减的softmax_loss_naive梯度：')
f = lambda w: softmax_loss_naive(w, X_sample, y_sample, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

print('检验加入权重衰减项后的softmax_loss_naive梯度：')
loss, grad = softmax_loss_naive(W, X_sample, y_sample, 1e2)
f = lambda w: softmax_loss_naive(w, X_sample, y_sample, 1e2)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# 检验无权重衰减的softmax_loss_naive梯度：
# numerical: -1.054613 analytic: -1.054613, relative error: 9.734112e-09
# numerical: -1.840080 analytic: -1.840080, relative error: 2.285202e-09
# numerical: 0.567554 analytic: 0.567554, relative error: 2.730675e-08
# numerical: -2.150248 analytic: -2.150248, relative error: 3.425218e-09
# numerical: -5.629661 analytic: -5.629661, relative error: 1.267920e-08
# numerical: 1.534296 analytic: 1.534296, relative error: 1.135726e-08
# numerical: -0.886858 analytic: -0.886858, relative error: 3.131884e-08
# numerical: 1.865959 analytic: 1.865959, relative error: 4.925597e-08
# numerical: 2.005196 analytic: 2.005196, relative error: 2.346463e-08
# numerical: 2.375505 analytic: 2.375505, relative error: 1.845468e-08
# 检验加入权重衰减项后的softmax_loss_naive梯度：
# numerical: 2.521616 analytic: 2.521616, relative error: 9.639698e-09
# numerical: 2.787637 analytic: 2.787637, relative error: 1.684614e-08
# numerical: -2.370324 analytic: -2.370324, relative error: 1.306798e-08
# numerical: -2.645675 analytic: -2.645675, relative error: 1.510461e-08
# numerical: -2.286746 analytic: -2.286746, relative error: 1.196671e-08
# numerical: -0.416809 analytic: -0.416809, relative error: 8.080014e-08
# numerical: -0.496479 analytic: -0.496479, relative error: 1.880075e-08
# numerical: -1.674693 analytic: -1.674693, relative error: 3.606955e-08
# numerical: -0.006981 analytic: -0.006981, relative error: 2.201888e-10
# numerical: -0.161266 analytic: -0.161266, relative error: 6.096331e-07

# %% [markdown]
# ## 3. 使用向量化表达计算损失函数以及梯度

# %%
# 现在我们将实现向量化的softmax损失及其梯度计算
# 打开softmax_loss_vectorized函数并完成相应任务，运行该段代码
# 向量化版本应该和显式循环版本相同，但前者的计算效率应该快速得很多
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_sample, y_sample, 0.00001)
toc = time.time()
print('显式循环版loss: %e   花费时间 %fs' % (loss_naive, toc - tic))

from classifiers.chapter2.softmax_loss import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_sample, y_sample, 0.00001)
toc = time.time()
print('向量化版本 loss: %e    花费时间 %fs' % (loss_vectorized, toc - tic))

# 比较结果
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('损失误差: %f' % np.abs(loss_naive - loss_vectorized))
print('梯度误差: %f' % grad_difference)
# Out:
# 显式循环版loss: 2.322968e+00   花费时间 0.057173s
# 向量化版本 loss: 2.322968e+00    花费时间 0.002102s
# 损失误差: 0.000000
# 梯度误差: 0.000000

# %% [markdown]
# ## 4.最小批量梯度下降算法 训练softmax分类器

# %%
# 打开softmax.trian()完成随机梯度下降任务，然后执行该段代码
from classifiers.chapter2.softmax import *
softmax = Softmax()
tic = time.time()
loss_hist = softmax.train(X_sample, y_sample, learning_rate=1e-7, reg=5e4,
                      num_iters=3500, verbose=True)
toc = time.time()
print('花费时间 %fs' % (toc - tic))
# Out:
# 迭代次数 0 / 3500: loss 770.911799
# 迭代次数 500 / 3500: loss 6.861723
# 迭代次数 1000 / 3500: loss 1.887898
# 迭代次数 1500 / 3500: loss 1.847649
# 迭代次数 2000 / 3500: loss 1.878568
# 迭代次数 2500 / 3500: loss 1.841795
# 迭代次数 3000 / 3500: loss 1.843624
# 花费时间 6.487389s

# %%
# 查看损失值的变化情况
plt.plot(loss_hist)
plt.xlabel('Iteration number')
plt.ylabel('Loss value')
plt.show()

# %%
# 测试训练集，验证集的精度
y_train_pred = softmax.predict(X_sample)
print(y_train_pred.shape)
print('训练数据量：%f    训练正确率: %f' % (X_sample.shape[0],np.mean(y_sample == y_train_pred), ))
y_val_pred = softmax.predict(X_val)
print('验证数据量：%f    验证正确率: %f' % (X_val.shape[0],np.mean(y_val == y_val_pred), ))
# Out:
# (250,)
# 训练数据量：250.000000    训练正确率: 0.608000
# 验证数据量：100.000000    验证正确率: 0.250000

# %% [markdown]
# ## 5.使用验证数据选择超参数

# %%
#使用验证集调整超参数(权重衰减因子，学习率)
from classifiers.chapter2.softmax import *
results = {}
best_val = -1
best_l = 0
best_r = 0
best_softmax = None
learning_rates=np.logspace(-9, 0, num=10)
regularization_strengths=np.logspace(0, 5, num=10)
batch_size = [50]
num_iters  = [300]

for b in batch_size:
    for n in num_iters:
        for l in learning_rates:
            for r in regularization_strengths:
                 softmax = Softmax()
                 loss_hist = softmax.train(X_sample, y_sample, 
                                           learning_rate=l,reg=r,
                                           num_iters=n,
                                           batch_size=b,
                                           verbose=False)
                 y_train_pred = softmax.predict(X_sample)
                 train_accuracy= np.mean(y_sample == y_train_pred)
                 y_val_pred = softmax.predict(X_val)
                 val_accuracy= np.mean(y_val == y_val_pred)
                 results[(l,r)]=(train_accuracy,val_accuracy)
                 if (best_val < val_accuracy):
                    best_val = val_accuracy
                    best_softmax = softmax
                    best_l =l
                    best_r =r
    
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print( 'lr %e reg %e 训练精度: %f 验证精度: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('最佳学习率为：%e 最佳权重衰减系数为：%e 其所对应的验证精度为: %f' % (best_l,best_r,best_val))
# Out:
# /home/sdtang/TsdFile/DLACTION/DLAction/classifiers/chapter2/softmax_loss.py:71: RuntimeWarning: divide by zero encountered in log
#   loss += -np.sum(y_trueClass * np.log(prob)) / num_train + 0.5 * reg * np.sum(W*W)
# /home/sdtang/TsdFile/DLACTION/DLAction/classifiers/chapter2/softmax_loss.py:71: RuntimeWarning: invalid value encountered in multiply
#   loss += -np.sum(y_trueClass * np.log(prob)) / num_train + 0.5 * reg * np.sum(W*W)
# /home/sdtang/TsdFile/DLACTION/DLAction/classifiers/chapter2/softmax_loss.py:71: RuntimeWarning: overflow encountered in double_scalars
#   loss += -np.sum(y_trueClass * np.log(prob)) / num_train + 0.5 * reg * np.sum(W*W)
# /home/sdtang/TsdFile/DLACTION/DLAction/classifiers/chapter2/softmax_loss.py:71: RuntimeWarning: overflow encountered in multiply
#   loss += -np.sum(y_trueClass * np.log(prob)) / num_train + 0.5 * reg * np.sum(W*W)
# /home/sdtang/TsdFile/DLACTION/DLAction/classifiers/chapter2/softmax_loss.py:64: RuntimeWarning: overflow encountered in subtract
#   scores = s - np.max(s, axis=1, keepdims=True)
# /home/sdtang/TsdFile/DLACTION/DLAction/classifiers/chapter2/softmax_loss.py:64: RuntimeWarning: invalid value encountered in subtract
#   scores = s - np.max(s, axis=1, keepdims=True)
# /home/sdtang/TsdFile/DLACTION/DLAction/classifiers/chapter2/softmax_loss.py:72: RuntimeWarning: overflow encountered in multiply
#   dW += -np.dot(X.T, y_trueClass-prob) / num_train + reg * W
# lr 1.000000e-09 reg 1.000000e+00 训练精度: 0.064000 验证精度: 0.110000
# lr 1.000000e-09 reg 3.593814e+00 训练精度: 0.124000 验证精度: 0.140000
# lr 1.000000e-09 reg 1.291550e+01 训练精度: 0.128000 验证精度: 0.080000
# lr 1.000000e-09 reg 4.641589e+01 训练精度: 0.116000 验证精度: 0.060000
# lr 1.000000e-09 reg 1.668101e+02 训练精度: 0.076000 验证精度: 0.070000
# lr 1.000000e-09 reg 5.994843e+02 训练精度: 0.196000 验证精度: 0.140000
# lr 1.000000e-09 reg 2.154435e+03 训练精度: 0.148000 验证精度: 0.100000
# lr 1.000000e-09 reg 7.742637e+03 训练精度: 0.080000 验证精度: 0.060000
# lr 1.000000e-09 reg 2.782559e+04 训练精度: 0.096000 验证精度: 0.080000
# lr 1.000000e-09 reg 1.000000e+05 训练精度: 0.120000 验证精度: 0.140000
# lr 1.000000e-08 reg 1.000000e+00 训练精度: 0.080000 验证精度: 0.110000
# lr 1.000000e-08 reg 3.593814e+00 训练精度: 0.100000 验证精度: 0.070000
# lr 1.000000e-08 reg 1.291550e+01 训练精度: 0.096000 验证精度: 0.060000
# lr 1.000000e-08 reg 4.641589e+01 训练精度: 0.108000 验证精度: 0.060000
# lr 1.000000e-08 reg 1.668101e+02 训练精度: 0.136000 验证精度: 0.070000
# lr 1.000000e-08 reg 5.994843e+02 训练精度: 0.116000 验证精度: 0.100000
# lr 1.000000e-08 reg 2.154435e+03 训练精度: 0.128000 验证精度: 0.110000
# lr 1.000000e-08 reg 7.742637e+03 训练精度: 0.104000 验证精度: 0.070000
# lr 1.000000e-08 reg 2.782559e+04 训练精度: 0.092000 验证精度: 0.100000
# lr 1.000000e-08 reg 1.000000e+05 训练精度: 0.152000 验证精度: 0.090000
# lr 1.000000e-07 reg 1.000000e+00 训练精度: 0.296000 验证精度: 0.100000
# lr 1.000000e-07 reg 3.593814e+00 训练精度: 0.284000 验证精度: 0.150000
# lr 1.000000e-07 reg 1.291550e+01 训练精度: 0.244000 验证精度: 0.210000
# lr 1.000000e-07 reg 4.641589e+01 训练精度: 0.240000 验证精度: 0.230000
# lr 1.000000e-07 reg 1.668101e+02 训练精度: 0.272000 验证精度: 0.180000
# lr 1.000000e-07 reg 5.994843e+02 训练精度: 0.256000 验证精度: 0.170000
# lr 1.000000e-07 reg 2.154435e+03 训练精度: 0.352000 验证精度: 0.130000
# lr 1.000000e-07 reg 7.742637e+03 训练精度: 0.308000 验证精度: 0.110000
# lr 1.000000e-07 reg 2.782559e+04 训练精度: 0.368000 验证精度: 0.190000
# lr 1.000000e-07 reg 1.000000e+05 训练精度: 0.492000 验证精度: 0.200000
# lr 1.000000e-06 reg 1.000000e+00 训练精度: 0.884000 验证精度: 0.160000
# lr 1.000000e-06 reg 3.593814e+00 训练精度: 0.888000 验证精度: 0.150000
# lr 1.000000e-06 reg 1.291550e+01 训练精度: 0.856000 验证精度: 0.210000
# lr 1.000000e-06 reg 4.641589e+01 训练精度: 0.896000 验证精度: 0.180000
# lr 1.000000e-06 reg 1.668101e+02 训练精度: 0.864000 验证精度: 0.260000
# lr 1.000000e-06 reg 5.994843e+02 训练精度: 0.880000 验证精度: 0.170000
# lr 1.000000e-06 reg 2.154435e+03 训练精度: 0.880000 验证精度: 0.200000
# lr 1.000000e-06 reg 7.742637e+03 训练精度: 0.832000 验证精度: 0.230000
# lr 1.000000e-06 reg 2.782559e+04 训练精度: 0.640000 验证精度: 0.210000
# lr 1.000000e-06 reg 1.000000e+05 训练精度: 0.472000 验证精度: 0.160000
# lr 1.000000e-05 reg 1.000000e+00 训练精度: 1.000000 验证精度: 0.230000
# lr 1.000000e-05 reg 3.593814e+00 训练精度: 1.000000 验证精度: 0.190000
# lr 1.000000e-05 reg 1.291550e+01 训练精度: 1.000000 验证精度: 0.170000
# lr 1.000000e-05 reg 4.641589e+01 训练精度: 1.000000 验证精度: 0.210000
# lr 1.000000e-05 reg 1.668101e+02 训练精度: 1.000000 验证精度: 0.170000
# lr 1.000000e-05 reg 5.994843e+02 训练精度: 0.996000 验证精度: 0.200000
# lr 1.000000e-05 reg 2.154435e+03 训练精度: 0.452000 验证精度: 0.130000
# lr 1.000000e-05 reg 7.742637e+03 训练精度: 0.536000 验证精度: 0.210000
# lr 1.000000e-05 reg 2.782559e+04 训练精度: 0.304000 验证精度: 0.150000
# lr 1.000000e-05 reg 1.000000e+05 训练精度: 0.096000 验证精度: 0.090000
# lr 1.000000e-04 reg 1.000000e+00 训练精度: 1.000000 验证精度: 0.240000
# lr 1.000000e-04 reg 3.593814e+00 训练精度: 1.000000 验证精度: 0.230000
# lr 1.000000e-04 reg 1.291550e+01 训练精度: 1.000000 验证精度: 0.220000
# lr 1.000000e-04 reg 4.641589e+01 训练精度: 1.000000 验证精度: 0.230000
# lr 1.000000e-04 reg 1.668101e+02 训练精度: 0.676000 验证精度: 0.230000
# lr 1.000000e-04 reg 5.994843e+02 训练精度: 0.412000 验证精度: 0.180000
# lr 1.000000e-04 reg 2.154435e+03 训练精度: 0.260000 验证精度: 0.240000
# lr 1.000000e-04 reg 7.742637e+03 训练精度: 0.104000 验证精度: 0.120000
# lr 1.000000e-04 reg 2.782559e+04 训练精度: 0.044000 验证精度: 0.050000
# lr 1.000000e-04 reg 1.000000e+05 训练精度: 0.092000 验证精度: 0.120000
# lr 1.000000e-03 reg 1.000000e+00 训练精度: 1.000000 验证精度: 0.230000
# lr 1.000000e-03 reg 3.593814e+00 训练精度: 1.000000 验证精度: 0.210000
# lr 1.000000e-03 reg 1.291550e+01 训练精度: 0.840000 验证精度: 0.190000
# lr 1.000000e-03 reg 4.641589e+01 训练精度: 0.416000 验证精度: 0.160000
# lr 1.000000e-03 reg 1.668101e+02 训练精度: 0.320000 验证精度: 0.110000
# lr 1.000000e-03 reg 5.994843e+02 训练精度: 0.188000 验证精度: 0.170000
# lr 1.000000e-03 reg 2.154435e+03 训练精度: 0.076000 验证精度: 0.050000
# lr 1.000000e-03 reg 7.742637e+03 训练精度: 0.096000 验证精度: 0.100000
# lr 1.000000e-03 reg 2.782559e+04 训练精度: 0.108000 验证精度: 0.070000
# lr 1.000000e-03 reg 1.000000e+05 训练精度: 0.108000 验证精度: 0.070000
# lr 1.000000e-02 reg 1.000000e+00 训练精度: 0.760000 验证精度: 0.210000
# lr 1.000000e-02 reg 3.593814e+00 训练精度: 0.432000 验证精度: 0.200000
# lr 1.000000e-02 reg 1.291550e+01 训练精度: 0.292000 验证精度: 0.130000
# lr 1.000000e-02 reg 4.641589e+01 训练精度: 0.300000 验证精度: 0.100000
# lr 1.000000e-02 reg 1.668101e+02 训练精度: 0.080000 验证精度: 0.100000
# lr 1.000000e-02 reg 5.994843e+02 训练精度: 0.080000 验证精度: 0.080000
# lr 1.000000e-02 reg 2.154435e+03 训练精度: 0.108000 验证精度: 0.070000
# lr 1.000000e-02 reg 7.742637e+03 训练精度: 0.108000 验证精度: 0.070000
# lr 1.000000e-02 reg 2.782559e+04 训练精度: 0.108000 验证精度: 0.070000
# lr 1.000000e-02 reg 1.000000e+05 训练精度: 0.108000 验证精度: 0.070000
# lr 1.000000e-01 reg 1.000000e+00 训练精度: 0.308000 验证精度: 0.160000
# lr 1.000000e-01 reg 3.593814e+00 训练精度: 0.196000 验证精度: 0.120000
# lr 1.000000e-01 reg 1.291550e+01 训练精度: 0.096000 验证精度: 0.110000
# lr 1.000000e-01 reg 4.641589e+01 训练精度: 0.104000 验证精度: 0.120000
# lr 1.000000e-01 reg 1.668101e+02 训练精度: 0.108000 验证精度: 0.070000
# lr 1.000000e-01 reg 5.994843e+02 训练精度: 0.108000 验证精度: 0.070000
# lr 1.000000e-01 reg 2.154435e+03 训练精度: 0.108000 验证精度: 0.070000
# lr 1.000000e-01 reg 7.742637e+03 训练精度: 0.108000 验证精度: 0.070000
# lr 1.000000e-01 reg 2.782559e+04 训练精度: 0.108000 验证精度: 0.070000
# lr 1.000000e-01 reg 1.000000e+05 训练精度: 0.108000 验证精度: 0.070000
# lr 1.000000e+00 reg 1.000000e+00 训练精度: 0.072000 验证精度: 0.080000
# lr 1.000000e+00 reg 3.593814e+00 训练精度: 0.032000 验证精度: 0.060000
# lr 1.000000e+00 reg 1.291550e+01 训练精度: 0.108000 验证精度: 0.070000
# lr 1.000000e+00 reg 4.641589e+01 训练精度: 0.108000 验证精度: 0.070000
# lr 1.000000e+00 reg 1.668101e+02 训练精度: 0.108000 验证精度: 0.070000
# lr 1.000000e+00 reg 5.994843e+02 训练精度: 0.108000 验证精度: 0.070000
# lr 1.000000e+00 reg 2.154435e+03 训练精度: 0.108000 验证精度: 0.070000
# lr 1.000000e+00 reg 7.742637e+03 训练精度: 0.108000 验证精度: 0.070000
# lr 1.000000e+00 reg 2.782559e+04 训练精度: 0.108000 验证精度: 0.070000
# lr 1.000000e+00 reg 1.000000e+05 训练精度: 0.108000 验证精度: 0.070000
# 最佳学习率为：1.000000e-06 最佳权重衰减系数为：1.668101e+02 其所对应的验证精度为: 0.260000

# %%
import math
x_scatter = [math.log10(x[0]) for x in results]
y_scatter = [math.log10(x[1]) for x in results]

# 绘制训练数据精度
marker_size = 100
colors = [results[x][0] for x in results]
plt.subplot(2, 1, 1)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 training accuracy')

#绘制验证数据精度
colors = [results[x][1] for x in results] 
plt.subplot(2, 1, 2)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 validation accuracy')
plt.show()

# %%
#使用验证集调整超参数(权重衰减因子，学习率)
from classifiers.chapter2.softmax import *
results = {}
best_val = -1
best_l = 0
best_r = 0
best_softmax = None
learning_rates=np.logspace(-6, -4, num=10)
regularization_strengths=np.logspace(-1, 4, num=5)
batch_size = [50]
num_iters  = [300]

for b in batch_size:
    for n in num_iters:
        for l in learning_rates:
            for r in regularization_strengths:
                 softmax = Softmax()
                 loss_hist = softmax.train(X_sample, y_sample,
                                           learning_rate=l, reg=r,
                                           num_iters=n,batch_size=b, verbose=False)
                 y_train_pred = softmax.predict(X_sample)
                 train_accuracy= np.mean(y_sample == y_train_pred)
                 y_val_pred = softmax.predict(X_val)
                 val_accuracy= np.mean(y_val == y_val_pred)
                 results[(l,r)]=(train_accuracy,val_accuracy)
                 if (best_val < val_accuracy):
                    best_val = val_accuracy
                    best_softmax = softmax
                    best_l =l
                    best_r =r

    
print('最佳学习率为：%e 最佳权重衰减系数为：%e 其所对应的验证精度为: %f' % (best_l,best_r,best_val))
# Out:
# 最佳学习率为：4.641589e-06 最佳权重衰减系数为：1.000000e-01 其所对应的验证精度为: 0.240000
# /home/sdtang/TsdFile/DLACTION/DLAction/classifiers/chapter2/softmax_loss.py:71: RuntimeWarning: divide by zero encountered in log
#   loss += -np.sum(y_trueClass * np.log(prob)) / num_train + 0.5 * reg * np.sum(W*W)
# /home/sdtang/TsdFile/DLACTION/DLAction/classifiers/chapter2/softmax_loss.py:71: RuntimeWarning: invalid value encountered in multiply
#   loss += -np.sum(y_trueClass * np.log(prob)) / num_train + 0.5 * reg * np.sum(W*W)

# %%
import math
x_scatter = [math.log10(x[0]) for x in results]
y_scatter = [math.log10(x[1]) for x in results]


# 绘制训练数据精度
marker_size = 100
colors = [results[x][0] for x in results]
plt.subplot(2, 1, 1)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 training accuracy')

#绘制验证数据精度
colors = [results[x][1] for x in results] 
plt.subplot(2, 1, 2)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 validation accuracy')
plt.show()

# %%
#使用验证集调整超参数(权重衰减因子，学习率)
from classifiers.chapter2.softmax import *
results = {}
best_val = -1
best_l = 0
best_r = 0
best_softmax = None
learning_rates=np.logspace(-5, -4, num=10)
regularization_strengths=np.logspace(-2, 3, num=5)
batch_size = [50]
num_iters  = [300]

for b in batch_size:
    for n in num_iters:
        for l in learning_rates:
            for r in regularization_strengths:
                 softmax = Softmax()
                 loss_hist = softmax.train(X_sample, y_sample, learning_rate=l,
                                           reg=r,num_iters=n,batch_size=b, verbose=False)
                 y_train_pred = softmax.predict(X_sample)
                 train_accuracy= np.mean(y_sample == y_train_pred)
                 y_val_pred = softmax.predict(X_val)
                 val_accuracy= np.mean(y_val == y_val_pred)
                 results[(l,r)]=(train_accuracy,val_accuracy)
                 if (best_val < val_accuracy):
                    best_val = val_accuracy
                    best_softmax = softmax
                    best_l =l
                    best_r =r

    
print('最佳学习率为：%e 最佳权重衰减系数为：%e 其所对应的验证精度为: %f' % (best_l,best_r,best_val))
# Out:
# 最佳学习率为：1.000000e-05 最佳权重衰减系数为：1.778279e-01 其所对应的验证精度为: 0.270000

# %%
import math
x_scatter = [math.log10(x[0]) for x in results]
y_scatter = [math.log10(x[1]) for x in results]

marker_size = 100
colors = [results[x][0] for x in results]
plt.subplot(2, 1, 1)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 training accuracy')


colors = [results[x][1] for x in results] 
plt.subplot(2, 1, 2)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 validation accuracy')
plt.show()

# %%
#在测试数据集上评估最佳softmax分类器
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('测试集精度: %f' % test_accuracy)
# Out:
# 测试集精度: 0.227600

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=10000):
  cifar10_dir = 'datasets/cifar-10-batches-py'
  X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir) 
  mask = range(num_training, num_training + num_validation)
  X_val = X_train[mask]
  y_val = y_train[mask]
  mask = range(num_training)
  X_train = X_train[mask]
  y_train = y_train[mask]
  mask = range(num_test)
  X_test = X_test[mask]
  y_test = y_test[mask]  
  X_train = np.reshape(X_train, (X_train.shape[0], -1))
  X_val = np.reshape(X_val, (X_val.shape[0], -1))
  X_test = np.reshape(X_test, (X_test.shape[0], -1))  
  mean_image = np.mean(X_train, axis = 0)
  X_train -= mean_image
  X_val -= mean_image
  X_test -= mean_image
  X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
  X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
  X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))]) 
  return X_train, y_train, X_val, y_val, X_test, y_test


X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (10000, 3073)
# Test labels shape:  (10000,)

# %%
from classifiers.chapter2.softmax import Softmax
results = {}
best_val = -1
best_softmax = None
################################################################################
#                            任务:                                             #
#               使用全部训练数据训练一个最佳softmax                            #
################################################################################
learning_rates = [1.4e-7, 1.45e-7, 1.5e-7, 1.55e-7, 1.6e-7]
regularization_strengths = [2.3e4, 2.6e4, 2.7e4, 2.8e4, 2.9e4]
for l in learning_rates:
    for r in regularization_strengths:
        softmax = Softmax()
        loss_hist = softmax.train(X_train, y_train, learning_rate=l, 
                                  reg=r,num_iters=2000, verbose=True)
        y_train_pred = softmax.predict(X_train)
        train_accuracy= np.mean(y_train == y_train_pred)
        y_val_pred = softmax.predict(X_val)
        val_accuracy= np.mean(y_val == y_val_pred)
        results[(l,r)]=(train_accuracy,val_accuracy)
        if (best_val < val_accuracy):
            best_val = val_accuracy
            best_softmax = softmax
################################################################################
#                            结束编码                                          #
################################################################################

for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('最佳验证精度为: %f' % best_val)
# Out:
# 迭代次数 0 / 2000: loss 359.358933
# 迭代次数 500 / 2000: loss 15.941260
# 迭代次数 1000 / 2000: loss 2.588986
# 迭代次数 1500 / 2000: loss 2.047571
# 迭代次数 0 / 2000: loss 401.003232
# 迭代次数 500 / 2000: loss 12.185783
# 迭代次数 1000 / 2000: loss 2.263843
# 迭代次数 1500 / 2000: loss 2.019916
# 迭代次数 0 / 2000: loss 425.873277
# 迭代次数 500 / 2000: loss 11.444100
# 迭代次数 1000 / 2000: loss 2.242713
# 迭代次数 1500 / 2000: loss 2.068394
# 迭代次数 0 / 2000: loss 436.706385
# 迭代次数 500 / 2000: loss 10.457795
# 迭代次数 1000 / 2000: loss 2.195074
# 迭代次数 1500 / 2000: loss 1.982648
# 迭代次数 0 / 2000: loss 449.242912
# 迭代次数 500 / 2000: loss 9.512830
# 迭代次数 1000 / 2000: loss 2.146298
# 迭代次数 1500 / 2000: loss 2.057081
# 迭代次数 0 / 2000: loss 357.760883
# 迭代次数 500 / 2000: loss 14.360513
# 迭代次数 1000 / 2000: loss 2.439938
# 迭代次数 1500 / 2000: loss 2.013108
# 迭代次数 0 / 2000: loss 394.579813
# 迭代次数 500 / 2000: loss 10.761828
# 迭代次数 1000 / 2000: loss 2.154230
# 迭代次数 1500 / 2000: loss 2.008525
# 迭代次数 0 / 2000: loss 419.762650
# 迭代次数 500 / 2000: loss 10.148379
# 迭代次数 1000 / 2000: loss 2.182061
# 迭代次数 1500 / 2000: loss 2.039443
# 迭代次数 0 / 2000: loss 435.687636
# 迭代次数 500 / 2000: loss 9.315181
# 迭代次数 1000 / 2000: loss 2.165778
# 迭代次数 1500 / 2000: loss 2.036861
# 迭代次数 0 / 2000: loss 450.071255
# 迭代次数 500 / 2000: loss 8.474654
# 迭代次数 1000 / 2000: loss 2.156593
# 迭代次数 1500 / 2000: loss 2.024666
# 迭代次数 0 / 2000: loss 361.845228
# 迭代次数 500 / 2000: loss 13.122409
# 迭代次数 1000 / 2000: loss 2.358563
# 迭代次数 1500 / 2000: loss 2.077413
# 迭代次数 0 / 2000: loss 400.256160
# 迭代次数 500 / 2000: loss 10.021363
# 迭代次数 1000 / 2000: loss 2.197724
# 迭代次数 1500 / 2000: loss 1.951544
# 迭代次数 0 / 2000: loss 418.163107
# 迭代次数 500 / 2000: loss 9.049244
# 迭代次数 1000 / 2000: loss 2.167225
# 迭代次数 1500 / 2000: loss 2.033723
# 迭代次数 0 / 2000: loss 438.419171
# 迭代次数 500 / 2000: loss 8.286771
# 迭代次数 1000 / 2000: loss 2.167694
# 迭代次数 1500 / 2000: loss 2.103722
# 迭代次数 0 / 2000: loss 447.343781
# 迭代次数 500 / 2000: loss 7.590168
# 迭代次数 1000 / 2000: loss 2.078869
# 迭代次数 1500 / 2000: loss 2.076584
# 迭代次数 0 / 2000: loss 362.499980
# 迭代次数 500 / 2000: loss 11.930650
# 迭代次数 1000 / 2000: loss 2.278941
# 迭代次数 1500 / 2000: loss 2.007338
# 迭代次数 0 / 2000: loss 404.704558
# 迭代次数 500 / 2000: loss 8.959179
# 迭代次数 1000 / 2000: loss 2.166257
# 迭代次数 1500 / 2000: loss 2.126850
# 迭代次数 0 / 2000: loss 421.837077
# 迭代次数 500 / 2000: loss 8.296359
# 迭代次数 1000 / 2000: loss 2.129369
# 迭代次数 1500 / 2000: loss 2.111191
# 迭代次数 0 / 2000: loss 438.542580
# 迭代次数 500 / 2000: loss 7.553128
# 迭代次数 1000 / 2000: loss 2.065650
# 迭代次数 1500 / 2000: loss 1.970929
# 迭代次数 0 / 2000: loss 456.505867
# 迭代次数 500 / 2000: loss 6.935925
# 迭代次数 1000 / 2000: loss 2.092968
# 迭代次数 1500 / 2000: loss 2.033551
# 迭代次数 0 / 2000: loss 358.257059
# 迭代次数 500 / 2000: loss 10.742640
# 迭代次数 1000 / 2000: loss 2.212934
# 迭代次数 1500 / 2000: loss 2.012024
# 迭代次数 0 / 2000: loss 404.542362
# 迭代次数 500 / 2000: loss 8.173764
# 迭代次数 1000 / 2000: loss 2.133139
# 迭代次数 1500 / 2000: loss 2.047437
# 迭代次数 0 / 2000: loss 419.587480
# 迭代次数 500 / 2000: loss 7.349037
# 迭代次数 1000 / 2000: loss 2.058704
# 迭代次数 1500 / 2000: loss 2.016230
# 迭代次数 0 / 2000: loss 432.653978
# 迭代次数 500 / 2000: loss 6.753201
# 迭代次数 1000 / 2000: loss 2.067759
# 迭代次数 1500 / 2000: loss 2.030033
# 迭代次数 0 / 2000: loss 448.446726
# 迭代次数 500 / 2000: loss 6.260684
# 迭代次数 1000 / 2000: loss 2.037201
# 迭代次数 1500 / 2000: loss 2.013045
# lr 1.400000e-07 reg 2.300000e+04 train accuracy: 0.355408 val accuracy: 0.358000
# lr 1.400000e-07 reg 2.600000e+04 train accuracy: 0.347633 val accuracy: 0.370000
# lr 1.400000e-07 reg 2.700000e+04 train accuracy: 0.347694 val accuracy: 0.364000
# lr 1.400000e-07 reg 2.800000e+04 train accuracy: 0.341449 val accuracy: 0.360000
# lr 1.400000e-07 reg 2.900000e+04 train accuracy: 0.342082 val accuracy: 0.358000
# lr 1.450000e-07 reg 2.300000e+04 train accuracy: 0.350980 val accuracy: 0.361000
# lr 1.450000e-07 reg 2.600000e+04 train accuracy: 0.345102 val accuracy: 0.370000
# lr 1.450000e-07 reg 2.700000e+04 train accuracy: 0.351122 val accuracy: 0.359000
# lr 1.450000e-07 reg 2.800000e+04 train accuracy: 0.347694 val accuracy: 0.364000
# lr 1.450000e-07 reg 2.900000e+04 train accuracy: 0.343959 val accuracy: 0.345000
# lr 1.500000e-07 reg 2.300000e+04 train accuracy: 0.349694 val accuracy: 0.364000
# lr 1.500000e-07 reg 2.600000e+04 train accuracy: 0.347755 val accuracy: 0.367000
# lr 1.500000e-07 reg 2.700000e+04 train accuracy: 0.349490 val accuracy: 0.366000
# lr 1.500000e-07 reg 2.800000e+04 train accuracy: 0.344041 val accuracy: 0.360000
# lr 1.500000e-07 reg 2.900000e+04 train accuracy: 0.347429 val accuracy: 0.364000
# lr 1.550000e-07 reg 2.300000e+04 train accuracy: 0.354000 val accuracy: 0.378000
# lr 1.550000e-07 reg 2.600000e+04 train accuracy: 0.351327 val accuracy: 0.367000
# lr 1.550000e-07 reg 2.700000e+04 train accuracy: 0.347408 val accuracy: 0.354000
# lr 1.550000e-07 reg 2.800000e+04 train accuracy: 0.351408 val accuracy: 0.366000
# lr 1.550000e-07 reg 2.900000e+04 train accuracy: 0.347245 val accuracy: 0.355000
# lr 1.600000e-07 reg 2.300000e+04 train accuracy: 0.353755 val accuracy: 0.362000
# lr 1.600000e-07 reg 2.600000e+04 train accuracy: 0.350224 val accuracy: 0.367000
# lr 1.600000e-07 reg 2.700000e+04 train accuracy: 0.351878 val accuracy: 0.369000
# lr 1.600000e-07 reg 2.800000e+04 train accuracy: 0.342510 val accuracy: 0.363000
# lr 1.600000e-07 reg 2.900000e+04 train accuracy: 0.346000 val accuracy: 0.359000
# 最佳验证精度为: 0.378000

# %%
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('测试集精度: %f' % test_accuracy)
# Out:
# 测试集精度: 0.351900

# %%
# 可视化学习到的参数
w = best_softmax.W[:-1,:] # 移除偏置项
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
  plt.subplot(2, 5, i + 1)
  #将权重缩放回0-255
  wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
  plt.imshow(wimg.astype('uint8'))
  plt.axis('off')
  plt.title(classes[i])
